# %%
from relpy.bdd import *

# %%
bdd = BDD()

# %%
a = range(10)
b = range(20)
c = range(30)

# %%
labels = [a, b, c, 'd', 'e', 'f', 'g', 'h', 'i']
[bdd.var(x) for x in labels]
# Out:
# [range(0, 10) [low: False, high: True],
#  range(0, 20) [low: False, high: True],
#  range(0, 30) [low: False, high: True],
#  d [low: False, high: True],
#  e [low: False, high: True],
#  f [low: False, high: True],
#  g [low: False, high: True],
#  h [low: False, high: True],
#  i [low: False, high: True]]

# %%
a = bdd.var('a')
b = bdd.var('b')
c = bdd.var('c')
d = bdd.var('d')

# %%
bdd.Ite(a, b, c).draw()

# %%
s = [bdd.var(x) for x in ['b', 'c', 'a', 'h', 'c']]

# %%
ex1 = createAndGate(bdd, s)

# %%
ex1.draw()

# %%
ex2 = createOrGate(bdd, s)

# %%
ex2.draw()

# %%
ex3 = createKofNGate(bdd, 3, 5, s)

# %%
s
# Out:
# [b [low: False, high: True],
#  c [low: False, high: True],
#  a [low: False, high: True],
#  h [low: False, high: True],
#  c [low: False, high: True]]

# %%
ex3.draw()

# %%
max(1,3,4)
# Out:
# 4
