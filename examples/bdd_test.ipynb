# %%
from relpy.bdd import *
import pydotplus
from IPython.display import Image

# %%
def draw(x):
    dotf = x.todot()
    g = pydotplus.graph_from_dot_data(dotf)
    return Image(g.create_png())

# %%
bdd = BDD()

# %%
a = range(10)
b = range(20)
c = range(30)

# %%
labels = [a, b, c, 'd', 'e', 'f', 'g', 'h', 'i']
[bdd.var(x) for x in labels]
# Out:
# [BDD(139761144444800),
#  BDD(139761144444688),
#  BDD(139761144444408),
#  BDD(139761144400976),
#  BDD(139761144399016),
#  BDD(139761323613824),
#  BDD(139761731904680),
#  BDD(139761731905296),
#  BDD(139761731905688)]

# %%
a = bdd.var('a')
b = bdd.var('b')
c = bdd.var('c')
d = bdd.var('d')

# %%
draw(bdd.Ite(a, b, c))

# %%
bdd.index
# Out:
# {range(0, 10): 0,
#  range(0, 20): 1,
#  range(0, 30): 2,
#  'd': 3,
#  'e': 4,
#  'f': 5,
#  'g': 6,
#  'h': 7,
#  'i': 8,
#  'a': 9,
#  'b': 10,
#  'c': 11}

# %%
s = [bdd.var(x) for x in ['b', 'c', 'a', 'h', 'c']]

# %%
ex1 = createAndGate(bdd, s)

# %%
draw(ex1)

# %%
ex2 = createOrGate(bdd, s)

# %%
draw(ex2)

# %%
ex3 = createKofNGate(bdd, 3, 5, s)

# %%
s
# Out:
# [BDD(139761144493280),
#  BDD(139761144493448),
#  BDD(139761144493392),
#  BDD(139761731905296),
#  BDD(139761144493448)]

# %%
draw(ex3)
